# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
kagTrainDat = pd.read_csv('~/Documents/git/DataMining/train.csv')
kagTestDat = pd.read_csv('~/Documents/git/DataMining/test.csv')

# %%
kagTrainDat.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ACTION</th>
#       <th>RESOURCE</th>
#       <th>MGR_ID</th>
#       <th>ROLE_ROLLUP_1</th>
#       <th>ROLE_ROLLUP_2</th>
#       <th>ROLE_DEPTNAME</th>
#       <th>ROLE_TITLE</th>
#       <th>ROLE_FAMILY_DESC</th>
#       <th>ROLE_FAMILY</th>
#       <th>ROLE_CODE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>39353</td>
#       <td>85475</td>
#       <td>117961</td>
#       <td>118300</td>
#       <td>123472</td>
#       <td>117905</td>
#       <td>117906</td>
#       <td>290919</td>
#       <td>117908</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>17183</td>
#       <td>1540</td>
#       <td>117961</td>
#       <td>118343</td>
#       <td>123125</td>
#       <td>118536</td>
#       <td>118536</td>
#       <td>308574</td>
#       <td>118539</td>
#     </tr>
#     <tr>
# ...

# %%
for series in kagTrainDat:
    unique, counts = np.unique(np.sort(kagTrainDat[series]), return_counts=True)
    print(series + " " + str(unique.size))

print(-np.log((1-0.001)/0.001))
# Out:
# ACTION 2
# RESOURCE 7518
# MGR_ID 4243
# ROLE_ROLLUP_1 128
# ROLE_ROLLUP_2 177
# ROLE_DEPTNAME 449
# ROLE_TITLE 343
# ROLE_FAMILY_DESC 2358
# ROLE_FAMILY 67
# ROLE_CODE 343
# -6.90675477865
